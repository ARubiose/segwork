# %%
import torch
import torch.nn as nn
import timm

# %% [markdown]
# ## Feature extractor

# %% [markdown]
# Timm models arguments for `create_model`
#  - Positional arguments
#    - Model name : `str`
#  - Keyword arguments
#    - Features_only : `bool` = True
#    - Pretrained : `bool`
#    - out_indices : `Tuple`
#    - output_stride : `int`
#
# Timm encoders attributes

# %%
print(timm.create_model.__code__.co_varnames)
print(timm.create_model.__defaults__)
# Out:
# ('model_name', 'pretrained', 'checkpoint_path', 'scriptable', 'exportable', 'no_jit', 'kwargs', 'source_name', 'drop_connect_rate', 'hf_default_cfg', 'create_fn', 'model')
# (False, '', None, None, None)

# %%
model_name = 'resnet18'
model_args = { "output_stride" : 8 }

model = timm.create_model(model_name, features_only=True, **model_args)
model.feature_info.info
# Out:
# [{'num_chs': 64, 'reduction': 2, 'module': 'act1'},
#  {'num_chs': 64, 'reduction': 4, 'module': 'layer1'},
#  {'num_chs': 128, 'reduction': 8, 'module': 'layer2'},
#  {'num_chs': 256, 'reduction': 8, 'module': 'layer3'},
#  {'num_chs': 512, 'reduction': 8, 'module': 'layer4'}]

# %%
x = torch.rand(2,3,224,224)
out = model(x)
print(f'Output of backbone is a {type(out)} of lenght {len(out)}')
print(f'Original input has a size of {x.size()}')
for idx, feature in enumerate(out):
    print(f'Feature {idx} has size {feature.size()}')
# Out:
# Output of backbone is a <class 'list'> of lenght 5
# Original input has a size of torch.Size([2, 3, 224, 224])
# Feature 0 has size torch.Size([2, 64, 112, 112])
# Feature 1 has size torch.Size([2, 64, 56, 56])
# Feature 2 has size torch.Size([2, 128, 28, 28])
# Feature 3 has size torch.Size([2, 256, 28, 28])
# Feature 4 has size torch.Size([2, 512, 28, 28])

# %%
model_list = timm.list_models()
compatible_encoders = []
incompatible_encoder = []
for model_name in model_list:
    print(f'Cheking {model_name}...')
    try:
        timm.create_model(model_name, features_only=True)
        compatible_encoders.append(model_name)
    except:
        incompatible_encoder.append(model_name)
# Out:
# Cheking adv_inception_v3...
# Cheking bat_resnext26ts...
# Cheking beit_base_patch16_224...
# Cheking beit_base_patch16_224_in22k...
# Cheking beit_base_patch16_384...
# Cheking beit_large_patch16_224...
# Cheking beit_large_patch16_224_in22k...
# Cheking beit_large_patch16_384...
# Cheking beit_large_patch16_512...
# Cheking botnet26t_256...
# Cheking botnet50ts_256...
# Cheking cait_m36_384...
# Cheking cait_m48_448...
# Cheking cait_s24_224...
# Cheking cait_s24_384...
# Cheking cait_s36_384...
# Cheking cait_xs24_384...
# Cheking cait_xxs24_224...
# Cheking cait_xxs24_384...
# Cheking cait_xxs36_224...
# Cheking cait_xxs36_384...
# Cheking coat_lite_mini...
# Cheking coat_lite_small...
# Cheking coat_lite_tiny...
# Cheking coat_mini...
# Cheking coat_tiny...
# Cheking convit_base...
# Cheking convit_small...
# Cheking convit_tiny...
# Cheking convmixer_768_32...
# Cheking convmixer_1024_20_ks9_p14...
# Cheking convmixer_1536_20...
# Cheking convnext_base...
# Cheking convnext_base_384_in22ft1k...
# Cheking convnext_base_in22ft1k...
# Cheking convnext_base_in22k...
# Cheking convnext_large...
# Cheking convnext_large_384_in22ft1k...
# Cheking convnext_large_in22ft1k...
# Cheking convnext_large_in22k...
# Cheking convnext_small...
# Cheking convnext_tiny...
# Cheking convnext_tiny_hnf...
# Cheking convnext_xlarge_384_in22ft1k...
# Cheking convnext_xlarge_in22ft1k...
# Cheking convnext_xlarge_in22k...
# Cheking crossvit_9_240...
# Cheking crossvit_9_dagger_240...
# Cheking crossvit_15_240...
# Cheking crossvit_15_dagger_240...
# Cheking crossvit_15_dagger_408...
# Cheking crossvit_18_240...
# Cheking crossvit_18_dagger_240...
# Cheking crossvit_18_dagger_408...
# Cheking crossvit_base_240...
# Cheking crossvit_small_240...
# Cheking crossvit_tiny_240...
# Cheking cspdarknet53...
# Cheking cspdarknet53_iabn...
# Cheking cspresnet50...
# Cheking cspresnet50d...
# Cheking cspresnet50w...
# Cheking cspresnext50...
# Cheking cspresnext50_iabn...
# Cheking darknet53...
# Cheking deit_base_distilled_patch16_224...
# Cheking deit_base_distilled_patch16_384...
# Cheking deit_base_patch16_224...
# Cheking deit_base_patch16_384...
# Cheking deit_small_distilled_patch16_224...
# Cheking deit_small_patch16_224...
# Cheking deit_tiny_distilled_patch16_224...
# Cheking deit_tiny_patch16_224...
# Cheking densenet121...
# Cheking densenet121d...
# Cheking densenet161...
# Cheking densenet169...
# Cheking densenet201...
# Cheking densenet264...
# Cheking densenet264d_iabn...
# Cheking densenetblur121d...
# Cheking dla34...
# Cheking dla46_c...
# Cheking dla46x_c...
# Cheking dla60...
# Cheking dla60_res2net...
# Cheking dla60_res2next...
# Cheking dla60x...
# Cheking dla60x_c...
# Cheking dla102...
# Cheking dla102x...
# Cheking dla102x2...
# Cheking dla169...
# Cheking dm_nfnet_f0...
# Cheking dm_nfnet_f1...
# Cheking dm_nfnet_f2...
# Cheking dm_nfnet_f3...
# Cheking dm_nfnet_f4...
# Cheking dm_nfnet_f5...
# Cheking dm_nfnet_f6...
# Cheking dpn68...
# Cheking dpn68b...
# Cheking dpn92...
# Cheking dpn98...
# Cheking dpn107...
# Cheking dpn131...
# Cheking eca_botnext26ts_256...
# Cheking eca_halonext26ts...
# Cheking eca_nfnet_l0...
# Cheking eca_nfnet_l1...
# Cheking eca_nfnet_l2...
# Cheking eca_nfnet_l3...
# Cheking eca_resnet33ts...
# Cheking eca_resnext26ts...
# Cheking eca_vovnet39b...
# Cheking ecaresnet26t...
# Cheking ecaresnet50d...
# Cheking ecaresnet50d_pruned...
# Cheking ecaresnet50t...
# Cheking ecaresnet101d...
# Cheking ecaresnet101d_pruned...
# Cheking ecaresnet200d...
# Cheking ecaresnet269d...
# Cheking ecaresnetlight...
# Cheking ecaresnext26t_32x4d...
# Cheking ecaresnext50t_32x4d...
# Cheking efficientnet_b0...
# Cheking efficientnet_b1...
# Cheking efficientnet_b1_pruned...
# Cheking efficientnet_b2...
# Cheking efficientnet_b2_pruned...
# Cheking efficientnet_b2a...
# Cheking efficientnet_b3...
# Cheking efficientnet_b3_pruned...
# Cheking efficientnet_b3a...
# Cheking efficientnet_b4...
# Cheking efficientnet_b5...
# Cheking efficientnet_b6...
# Cheking efficientnet_b7...
# Cheking efficientnet_b8...
# Cheking efficientnet_cc_b0_4e...
# Cheking efficientnet_cc_b0_8e...
# Cheking efficientnet_cc_b1_8e...
# Cheking efficientnet_el...
# Cheking efficientnet_el_pruned...
# Cheking efficientnet_em...
# Cheking efficientnet_es...
# Cheking efficientnet_es_pruned...
# Cheking efficientnet_l2...
# Cheking efficientnet_lite0...
# Cheking efficientnet_lite1...
# Cheking efficientnet_lite2...
# Cheking efficientnet_lite3...
# Cheking efficientnet_lite4...
# Cheking efficientnetv2_l...
# Cheking efficientnetv2_m...
# Cheking efficientnetv2_rw_m...
# Cheking efficientnetv2_rw_s...
# Cheking efficientnetv2_rw_t...
# Cheking efficientnetv2_s...
# Cheking efficientnetv2_xl...
# Cheking ens_adv_inception_resnet_v2...
# Cheking ese_vovnet19b_dw...
# Cheking ese_vovnet19b_slim...
# Cheking ese_vovnet19b_slim_dw...
# Cheking ese_vovnet39b...
# Cheking ese_vovnet39b_evos...
# Cheking ese_vovnet57b...
# Cheking ese_vovnet99b...
# Cheking ese_vovnet99b_iabn...
# Cheking fbnetc_100...
# Cheking fbnetv3_b...
# Cheking fbnetv3_d...
# Cheking fbnetv3_g...
# Cheking gc_efficientnetv2_rw_t...
# Cheking gcresnet33ts...
# Cheking gcresnet50t...
# Cheking gcresnext26ts...
# Cheking gcresnext50ts...
# Cheking gernet_l...
# Cheking gernet_m...
# Cheking gernet_s...
# Cheking ghostnet_050...
# Cheking ghostnet_100...
# Cheking ghostnet_130...
# Cheking gluon_inception_v3...
# Cheking gluon_resnet18_v1b...
# Cheking gluon_resnet34_v1b...
# Cheking gluon_resnet50_v1b...
# Cheking gluon_resnet50_v1c...
# Cheking gluon_resnet50_v1d...
# Cheking gluon_resnet50_v1s...
# Cheking gluon_resnet101_v1b...
# Cheking gluon_resnet101_v1c...
# Cheking gluon_resnet101_v1d...
# Cheking gluon_resnet101_v1s...
# Cheking gluon_resnet152_v1b...
# Cheking gluon_resnet152_v1c...
# Cheking gluon_resnet152_v1d...
# Cheking gluon_resnet152_v1s...
# Cheking gluon_resnext50_32x4d...
# Cheking gluon_resnext101_32x4d...
# Cheking gluon_resnext101_64x4d...
# Cheking gluon_senet154...
# Cheking gluon_seresnext50_32x4d...
# Cheking gluon_seresnext101_32x4d...
# Cheking gluon_seresnext101_64x4d...
# Cheking gluon_xception65...
# Cheking gmixer_12_224...
# Cheking gmixer_24_224...
# Cheking gmlp_b16_224...
# Cheking gmlp_s16_224...
# Cheking gmlp_ti16_224...
# Cheking halo2botnet50ts_256...
# Cheking halonet26t...
# Cheking halonet50ts...
# Cheking halonet_h1...
# Cheking haloregnetz_b...
# Cheking hardcorenas_a...
# Cheking hardcorenas_b...
# Cheking hardcorenas_c...
# Cheking hardcorenas_d...
# Cheking hardcorenas_e...
# Cheking hardcorenas_f...
# Cheking hrnet_w18...
# Cheking hrnet_w18_small...
# Cheking hrnet_w18_small_v2...
# Cheking hrnet_w30...
# Cheking hrnet_w32...
# Cheking hrnet_w40...
# Cheking hrnet_w44...
# Cheking hrnet_w48...
# Cheking hrnet_w64...
# Cheking ig_resnext101_32x8d...
# Cheking ig_resnext101_32x16d...
# Cheking ig_resnext101_32x32d...
# Cheking ig_resnext101_32x48d...
# Cheking inception_resnet_v2...
# Cheking inception_v3...
# Cheking inception_v4...
# Cheking jx_nest_base...
# Cheking jx_nest_small...
# Cheking jx_nest_tiny...
# Cheking lambda_resnet26rpt_256...
# f:\Desarrollo software\segwork\.venv\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Cheking lambda_resnet26t...
# Cheking lambda_resnet50ts...
# Cheking lamhalobotnet50ts_256...
# Cheking lcnet_035...
# Cheking lcnet_050...
# Cheking lcnet_075...
# Cheking lcnet_100...
# Cheking lcnet_150...
# Cheking legacy_senet154...
# Cheking legacy_seresnet18...
# Cheking legacy_seresnet34...
# Cheking legacy_seresnet50...
# Cheking legacy_seresnet101...
# Cheking legacy_seresnet152...
# Cheking legacy_seresnext26_32x4d...
# Cheking legacy_seresnext50_32x4d...
# Cheking legacy_seresnext101_32x4d...
# Cheking levit_128...
# Cheking levit_128s...
# Cheking levit_192...
# Cheking levit_256...
# Cheking levit_384...
# Cheking mixer_b16_224...
# Cheking mixer_b16_224_in21k...
# Cheking mixer_b16_224_miil...
# Cheking mixer_b16_224_miil_in21k...
# Cheking mixer_b32_224...
# Cheking mixer_l16_224...
# Cheking mixer_l16_224_in21k...
# Cheking mixer_l32_224...
# Cheking mixer_s16_224...
# Cheking mixer_s32_224...
# Cheking mixnet_l...
# Cheking mixnet_m...
# Cheking mixnet_s...
# Cheking mixnet_xl...
# Cheking mixnet_xxl...
# Cheking mnasnet_050...
# Cheking mnasnet_075...
# Cheking mnasnet_100...
# Cheking mnasnet_140...
# Cheking mnasnet_a1...
# Cheking mnasnet_b1...
# Cheking mnasnet_small...
# Cheking mobilenetv2_035...
# Cheking mobilenetv2_050...
# Cheking mobilenetv2_075...
# Cheking mobilenetv2_100...
# Cheking mobilenetv2_110d...
# Cheking mobilenetv2_120d...
# Cheking mobilenetv2_140...
# Cheking mobilenetv3_large_075...
# Cheking mobilenetv3_large_100...
# Cheking mobilenetv3_large_100_miil...
# Cheking mobilenetv3_large_100_miil_in21k...
# Cheking mobilenetv3_rw...
# Cheking mobilenetv3_small_050...
# Cheking mobilenetv3_small_075...
# Cheking mobilenetv3_small_100...
# Cheking nasnetalarge...
# Cheking nest_base...
# Cheking nest_small...
# Cheking nest_tiny...
# Cheking nf_ecaresnet26...
# Cheking nf_ecaresnet50...
# Cheking nf_ecaresnet101...
# Cheking nf_regnet_b0...
# Cheking nf_regnet_b1...
# Cheking nf_regnet_b2...
# Cheking nf_regnet_b3...
# Cheking nf_regnet_b4...
# Cheking nf_regnet_b5...
# Cheking nf_resnet26...
# Cheking nf_resnet50...
# Cheking nf_resnet101...
# Cheking nf_seresnet26...
# Cheking nf_seresnet50...
# Cheking nf_seresnet101...
# Cheking nfnet_f0...
# Cheking nfnet_f0s...
# Cheking nfnet_f1...
# Cheking nfnet_f1s...
# Cheking nfnet_f2...
# Cheking nfnet_f2s...
# Cheking nfnet_f3...
# Cheking nfnet_f3s...
# Cheking nfnet_f4...
# Cheking nfnet_f4s...
# Cheking nfnet_f5...
# Cheking nfnet_f5s...
# Cheking nfnet_f6...
# Cheking nfnet_f6s...
# Cheking nfnet_f7...
# Cheking nfnet_f7s...
# Cheking nfnet_l0...
# Cheking pit_b_224...
# Cheking pit_b_distilled_224...
# Cheking pit_s_224...
# Cheking pit_s_distilled_224...
# Cheking pit_ti_224...
# Cheking pit_ti_distilled_224...
# Cheking pit_xs_224...
# Cheking pit_xs_distilled_224...
# Cheking pnasnet5large...
# Cheking regnetx_002...
# Cheking regnetx_004...
# Cheking regnetx_006...
# Cheking regnetx_008...
# Cheking regnetx_016...
# Cheking regnetx_032...
# Cheking regnetx_040...
# Cheking regnetx_064...
# Cheking regnetx_080...
# Cheking regnetx_120...
# Cheking regnetx_160...
# Cheking regnetx_320...
# Cheking regnety_002...
# Cheking regnety_004...
# Cheking regnety_006...
# Cheking regnety_008...
# Cheking regnety_016...
# Cheking regnety_032...
# Cheking regnety_040...
# Cheking regnety_064...
# Cheking regnety_080...
# Cheking regnety_120...
# Cheking regnety_160...
# Cheking regnety_320...
# Cheking regnetz_b16...
# Cheking regnetz_c16...
# Cheking regnetz_d8...
# Cheking regnetz_d8_evob...
# Cheking regnetz_d8_evos...
# Cheking regnetz_d32...
# Cheking regnetz_e8...
# Cheking repvgg_a2...
# Cheking repvgg_b0...
# Cheking repvgg_b1...
# Cheking repvgg_b1g4...
# Cheking repvgg_b2...
# Cheking repvgg_b2g4...
# Cheking repvgg_b3...
# Cheking repvgg_b3g4...
# Cheking res2net50_14w_8s...
# Cheking res2net50_26w_4s...
# Cheking res2net50_26w_6s...
# Cheking res2net50_26w_8s...
# Cheking res2net50_48w_2s...
# Cheking res2net101_26w_4s...
# Cheking res2next50...
# Cheking resmlp_12_224...
# Cheking resmlp_12_224_dino...
# Cheking resmlp_12_distilled_224...
# Cheking resmlp_24_224...
# Cheking resmlp_24_224_dino...
# Cheking resmlp_24_distilled_224...
# Cheking resmlp_36_224...
# Cheking resmlp_36_distilled_224...
# Cheking resmlp_big_24_224...
# Cheking resmlp_big_24_224_in22ft1k...
# Cheking resmlp_big_24_distilled_224...
# Cheking resnest14d...
# Cheking resnest26d...
# Cheking resnest50d...
# Cheking resnest50d_1s4x24d...
# Cheking resnest50d_4s2x40d...
# Cheking resnest101e...
# Cheking resnest200e...
# Cheking resnest269e...
# Cheking resnet18...
# Cheking resnet18d...
# Cheking resnet26...
# Cheking resnet26d...
# Cheking resnet26t...
# Cheking tf_efficientnetv2_xl_in21k...
# Cheking tf_inception_v3...
# Cheking tf_mixnet_l...
# Cheking tf_mixnet_m...
# Cheking tf_mixnet_s...
# Cheking tf_mobilenetv3_large_075...
# Cheking tf_mobilenetv3_large_100...
# Cheking tf_mobilenetv3_large_minimal_100...
# Cheking tf_mobilenetv3_small_075...
# Cheking tf_mobilenetv3_small_100...
# Cheking tf_mobilenetv3_small_minimal_100...
# Cheking tinynet_a...
# Cheking tinynet_b...
# Cheking tinynet_c...
# Cheking tinynet_d...
# Cheking tinynet_e...
# Cheking tnt_b_patch16_224...
# Cheking tnt_s_patch16_224...
# Cheking tresnet_l...
# Cheking tresnet_l_448...
# Cheking tresnet_m...
# Cheking tresnet_m_448...
# Cheking tresnet_m_miil_in21k...
# Cheking tresnet_xl...
# Cheking tresnet_xl_448...
# Cheking tv_densenet121...
# Cheking tv_resnet34...
# Cheking tv_resnet50...
# Cheking tv_resnet101...
# Cheking tv_resnet152...
# Cheking tv_resnext50_32x4d...
# Cheking twins_pcpvt_base...
# Cheking twins_pcpvt_large...
# Cheking twins_pcpvt_small...
# Cheking twins_svt_base...
# Cheking twins_svt_large...
# Cheking twins_svt_small...
# Cheking vgg11...
# Cheking vgg11_bn...
# Cheking vgg13...
# Cheking vgg13_bn...
# Cheking vgg16...
# Cheking vgg16_bn...
# Cheking vgg19...
# Cheking vgg19_bn...
# Cheking visformer_small...
# Cheking visformer_tiny...
# Cheking vit_base_patch8_224...
# Cheking vit_base_patch8_224_in21k...
# Cheking vit_base_patch16_224...
# Cheking vit_base_patch16_224_in21k...
# Cheking vit_base_patch16_224_miil...
# Cheking vit_base_patch16_224_miil_in21k...
# Cheking vit_base_patch16_384...
# Cheking vit_base_patch16_sam_224...
# Cheking vit_base_patch32_224...
# Cheking vit_base_patch32_224_in21k...
# Cheking vit_base_patch32_384...
# Cheking vit_base_patch32_sam_224...
# Cheking vit_base_r26_s32_224...
# Cheking vit_base_r50_s16_224...
# Cheking vit_base_r50_s16_224_in21k...
# Cheking vit_base_r50_s16_384...
# Cheking vit_base_resnet26d_224...
# Cheking vit_base_resnet50_224_in21k...
# Cheking vit_base_resnet50_384...
# Cheking vit_base_resnet50d_224...
# Cheking vit_giant_patch14_224...
# Cheking vit_gigantic_patch14_224...
# Cheking vit_huge_patch14_224...
# Cheking vit_huge_patch14_224_in21k...
# Cheking vit_large_patch16_224...
# Cheking vit_large_patch16_224_in21k...
# Cheking vit_large_patch16_384...
# Cheking vit_large_patch32_224...
# Cheking vit_large_patch32_224_in21k...
# Cheking vit_large_patch32_384...
# Cheking vit_large_r50_s32_224...
# Cheking vit_large_r50_s32_224_in21k...
# Cheking vit_large_r50_s32_384...
# Cheking vit_small_patch16_224...
# Cheking vit_small_patch16_224_in21k...
# Cheking vit_small_patch16_384...
# Cheking vit_small_patch32_224...
# Cheking vit_small_patch32_224_in21k...
# Cheking vit_small_patch32_384...
# Cheking vit_small_r26_s32_224...
# Cheking vit_small_r26_s32_224_in21k...
# Cheking vit_small_r26_s32_384...
# Cheking vit_small_resnet26d_224...
# Cheking vit_small_resnet50d_s16_224...
# Cheking vit_tiny_patch16_224...
# Cheking vit_tiny_patch16_224_in21k...
# Cheking vit_tiny_patch16_384...
# Cheking vit_tiny_r_s16_p8_224...
# Cheking vit_tiny_r_s16_p8_224_in21k...
# Cheking vit_tiny_r_s16_p8_384...
# Cheking vovnet39a...
# Cheking vovnet57a...
# Cheking wide_resnet50_2...
# Cheking wide_resnet101_2...
# Cheking xception...
# Cheking xception41...
# Cheking xception65...
# Cheking xception71...
# Cheking xcit_large_24_p8_224...
# Cheking xcit_large_24_p8_224_dist...
# Cheking xcit_large_24_p8_384_dist...
# Cheking xcit_large_24_p16_224...
# Cheking xcit_large_24_p16_224_dist...
# Cheking xcit_large_24_p16_384_dist...
# Cheking xcit_medium_24_p8_224...
# Cheking xcit_medium_24_p8_224_dist...
# Cheking xcit_medium_24_p8_384_dist...
# Cheking xcit_medium_24_p16_224...
# Cheking xcit_medium_24_p16_224_dist...
# Cheking xcit_medium_24_p16_384_dist...
# Cheking xcit_nano_12_p8_224...
# Cheking xcit_nano_12_p8_224_dist...
# Cheking xcit_nano_12_p8_384_dist...
# Cheking xcit_nano_12_p16_224...
# Cheking xcit_nano_12_p16_224_dist...
# Cheking xcit_nano_12_p16_384_dist...
# Cheking xcit_small_12_p8_224...
# Cheking xcit_small_12_p8_224_dist...
# Cheking xcit_small_12_p8_384_dist...
# Cheking xcit_small_12_p16_224...
# Cheking xcit_small_12_p16_224_dist...
# Cheking xcit_small_12_p16_384_dist...
# Cheking xcit_small_24_p8_224...
# Cheking xcit_small_24_p8_224_dist...
# Cheking xcit_small_24_p8_384_dist...
# Cheking xcit_small_24_p16_224...
# Cheking xcit_small_24_p16_224_dist...
# Cheking xcit_small_24_p16_384_dist...
# Cheking xcit_tiny_12_p8_224...
# Cheking xcit_tiny_12_p8_224_dist...
# Cheking xcit_tiny_12_p8_384_dist...
# Cheking xcit_tiny_12_p16_224...
# Cheking xcit_tiny_12_p16_224_dist...
# Cheking xcit_tiny_12_p16_384_dist...
# Cheking xcit_tiny_24_p8_224...
# Cheking xcit_tiny_24_p8_224_dist...
# Cheking xcit_tiny_24_p8_384_dist...
# Cheking xcit_tiny_24_p16_224...
# Cheking xcit_tiny_24_p16_224_dist...
# Cheking xcit_tiny_24_p16_384_dist...

# %%
with open('compatible models.txt', 'w') as f:
    for model_name in compatible_encoders:
        f.writelines(f'{model_name}\n')
        
with open('incompatible models.txt', 'w') as f:
    for model_name in incompatible_encoder:
        f.writelines(f'{model_name}\n')

# %%
import json 

timm_info = dict()
with open('compatible models.txt', 'r') as f:
    for line in f:
        model_name = line.strip()
        print(f'Processing {model_name}')
        model = timm.create_model(model_name, features_only=True)
        timm_info[model_name] = model.feature_info.info

with open('timm_info.json', 'w') as fjson:
    print('Dumping information...')
    json.dump(timm_info, fjson)
# Out:
# Processing adv_inception_v3
# Processing bat_resnext26ts
# Processing botnet26t_256
# Processing botnet50ts_256
# Processing convnext_base
# Processing convnext_base_384_in22ft1k
# Processing convnext_base_in22ft1k
# Processing convnext_base_in22k
# Processing convnext_large
# Processing convnext_large_384_in22ft1k
# Processing convnext_large_in22ft1k
# Processing convnext_large_in22k
# Processing convnext_small
# Processing convnext_tiny
# Processing convnext_tiny_hnf
# Processing convnext_xlarge_384_in22ft1k
# Processing convnext_xlarge_in22ft1k
# Processing convnext_xlarge_in22k
# Processing cspdarknet53
# Processing cspdarknet53_iabn
# Processing cspresnet50
# Processing cspresnet50d
# Processing cspresnet50w
# Processing cspresnext50
# Processing cspresnext50_iabn
# Processing darknet53
# Processing densenet121
# Processing densenet121d
# Processing densenet161
# Processing densenet169
# Processing densenet201
# Processing densenet264
# Processing densenet264d_iabn
# Processing densenetblur121d
# Processing dla34
# Processing dla46_c
# Processing dla46x_c
# Processing dla60
# Processing dla60_res2net
# Processing dla60_res2next
# Processing dla60x
# Processing dla60x_c
# Processing dla102
# Processing dla102x
# Processing dla102x2
# Processing dla169
# Processing dm_nfnet_f0
# Processing dm_nfnet_f1
# Processing dm_nfnet_f2
# Processing dm_nfnet_f3
# Processing dm_nfnet_f4
# Processing dm_nfnet_f5
# Processing dm_nfnet_f6
# Processing dpn68
# Processing dpn68b
# Processing dpn92
# Processing dpn98
# Processing dpn107
# Processing dpn131
# Processing eca_botnext26ts_256
# Processing eca_halonext26ts
# Processing eca_nfnet_l0
# Processing eca_nfnet_l1
# Processing eca_nfnet_l2
# Processing eca_nfnet_l3
# Processing eca_resnet33ts
# Processing eca_resnext26ts
# Processing eca_vovnet39b
# Processing ecaresnet26t
# Processing ecaresnet50d
# Processing ecaresnet50d_pruned
# Processing ecaresnet50t
# Processing ecaresnet101d
# Processing ecaresnet101d_pruned
# Processing ecaresnet200d
# Processing ecaresnet269d
# Processing ecaresnetlight
# Processing ecaresnext26t_32x4d
# Processing ecaresnext50t_32x4d
# Processing efficientnet_b0
# Processing efficientnet_b1
# Processing efficientnet_b1_pruned
# Processing efficientnet_b2
# Processing efficientnet_b2_pruned
# Processing efficientnet_b2a
# Processing efficientnet_b3
# Processing efficientnet_b3_pruned
# Processing efficientnet_b3a
# Processing efficientnet_b4
# Processing efficientnet_b5
# Processing efficientnet_b6
# Processing efficientnet_b7
# Processing efficientnet_b8
# Processing efficientnet_cc_b0_4e
# Processing efficientnet_cc_b0_8e
# Processing efficientnet_cc_b1_8e
# Processing efficientnet_el
# Processing efficientnet_el_pruned
# Processing efficientnet_em
# Processing efficientnet_es
# Processing efficientnet_es_pruned
# Processing efficientnet_l2
# Processing efficientnet_lite0
# Processing efficientnet_lite1
# Processing efficientnet_lite2
# Processing efficientnet_lite3
# Processing efficientnet_lite4
# Processing efficientnetv2_l
# Processing efficientnetv2_m
# Processing efficientnetv2_rw_m
# Processing efficientnetv2_rw_s
# Processing efficientnetv2_rw_t
# Processing efficientnetv2_s
# Processing efficientnetv2_xl
# Processing ens_adv_inception_resnet_v2
# Processing ese_vovnet19b_dw
# Processing ese_vovnet19b_slim
# Processing ese_vovnet19b_slim_dw
# Processing ese_vovnet39b
# Processing ese_vovnet39b_evos
# Processing ese_vovnet57b
# Processing ese_vovnet99b
# Processing ese_vovnet99b_iabn
# Processing fbnetc_100
# Processing fbnetv3_b
# Processing fbnetv3_d
# Processing fbnetv3_g
# Processing gc_efficientnetv2_rw_t
# Processing gcresnet33ts
# Processing gcresnet50t
# Processing gcresnext26ts
# Processing gcresnext50ts
# Processing gernet_l
# Processing gernet_m
# Processing gernet_s
# Processing ghostnet_050
# Processing ghostnet_100
# Processing ghostnet_130
# Processing gluon_inception_v3
# Processing gluon_resnet18_v1b
# Processing gluon_resnet34_v1b
# Processing gluon_resnet50_v1b
# Processing gluon_resnet50_v1c
# Processing gluon_resnet50_v1d
# Processing gluon_resnet50_v1s
# Processing gluon_resnet101_v1b
# Processing gluon_resnet101_v1c
# Processing gluon_resnet101_v1d
# Processing gluon_resnet101_v1s
# Processing gluon_resnet152_v1b
# Processing gluon_resnet152_v1c
# Processing gluon_resnet152_v1d
# Processing gluon_resnet152_v1s
# Processing gluon_resnext50_32x4d
# Processing gluon_resnext101_32x4d
# Processing gluon_resnext101_64x4d
# Processing gluon_senet154
# Processing gluon_seresnext50_32x4d
# Processing gluon_seresnext101_32x4d
# Processing gluon_seresnext101_64x4d
# Processing gluon_xception65
# Processing halo2botnet50ts_256
# Processing halonet26t
# Processing halonet50ts
# Processing halonet_h1
# Processing haloregnetz_b
# Processing hardcorenas_a
# Processing hardcorenas_b
# Processing hardcorenas_c
# Processing hardcorenas_d
# Processing hardcorenas_e
# Processing hardcorenas_f
# Processing hrnet_w18
# Processing hrnet_w18_small
# Processing hrnet_w18_small_v2
# Processing hrnet_w30
# Processing hrnet_w32
# Processing hrnet_w40
# Processing hrnet_w44
# Processing hrnet_w48
# Processing hrnet_w64
# Processing ig_resnext101_32x8d
# Processing ig_resnext101_32x16d
# Processing ig_resnext101_32x32d
# Processing ig_resnext101_32x48d
# Processing inception_resnet_v2
# Processing inception_v3
# Processing inception_v4
# Processing jx_nest_base
# Processing jx_nest_small
# Processing jx_nest_tiny
# Processing lambda_resnet26rpt_256
# f:\Desarrollo software\segwork\.venv\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Processing lambda_resnet26t
# Processing lambda_resnet50ts
# Processing lamhalobotnet50ts_256
# Processing lcnet_035
# Processing lcnet_050
# Processing lcnet_075
# Processing lcnet_100
# Processing lcnet_150
# Processing legacy_senet154
# Processing legacy_seresnet18
# Processing legacy_seresnet34
# Processing legacy_seresnet50
# Processing legacy_seresnet101
# Processing legacy_seresnet152
# Processing legacy_seresnext26_32x4d
# Processing legacy_seresnext50_32x4d
# Processing legacy_seresnext101_32x4d
# Processing mixnet_l
# Processing mixnet_m
# Processing mixnet_s
# Processing mixnet_xl
# Processing mixnet_xxl
# Processing mnasnet_050
# Processing mnasnet_075
# Processing mnasnet_100
# Processing mnasnet_140
# Processing mnasnet_a1
# Processing mnasnet_b1
# Processing mnasnet_small
# Processing mobilenetv2_035
# Processing mobilenetv2_050
# Processing mobilenetv2_075
# Processing mobilenetv2_100
# Processing mobilenetv2_110d
# Processing mobilenetv2_120d
# Processing mobilenetv2_140
# Processing mobilenetv3_large_075
# Processing mobilenetv3_large_100
# Processing mobilenetv3_large_100_miil
# Processing mobilenetv3_large_100_miil_in21k
# Processing mobilenetv3_rw
# Processing mobilenetv3_small_050
# Processing mobilenetv3_small_075
# Processing mobilenetv3_small_100
# Processing nasnetalarge
# Processing nest_base
# Processing nest_small
# Processing nest_tiny
# Processing nf_ecaresnet26
# Processing nf_ecaresnet50
# Processing nf_ecaresnet101
# Processing nf_regnet_b0
# Processing nf_regnet_b1
# Processing nf_regnet_b2
# Processing nf_regnet_b3
# Processing nf_regnet_b4
# Processing nf_regnet_b5
# Processing nf_resnet26
# Processing nf_resnet50
# Processing nf_resnet101
# Processing nf_seresnet26
# Processing nf_seresnet50
# Processing nf_seresnet101
# Processing nfnet_f0
# Processing nfnet_f0s
# Processing nfnet_f1
# Processing nfnet_f1s
# Processing nfnet_f2
# Processing nfnet_f2s
# Processing nfnet_f3
# Processing nfnet_f3s
# Processing nfnet_f4
# Processing nfnet_f4s
# Processing nfnet_f5
# Processing nfnet_f5s
# Processing nfnet_f6
# Processing nfnet_f6s
# Processing nfnet_f7
# Processing nfnet_f7s
# Processing nfnet_l0
# Processing pnasnet5large
# Processing regnetx_002
# Processing regnetx_004
# Processing regnetx_006
# Processing regnetx_008
# Processing regnetx_016
# Processing regnetx_032
# Processing regnetx_040
# Processing regnetx_064
# Processing regnetx_080
# Processing regnetx_120
# Processing regnetx_160
# Processing regnetx_320
# Processing regnety_002
# Processing regnety_004
# Processing regnety_006
# Processing regnety_008
# Processing regnety_016
# Processing regnety_032
# Processing regnety_040
# Processing regnety_064
# Processing regnety_080
# Processing regnety_120
# Processing regnety_160
# Processing regnety_320
# Processing regnetz_b16
# Processing regnetz_c16
# Processing regnetz_d8
# Processing regnetz_d8_evob
# Processing regnetz_d8_evos
# Processing regnetz_d32
# Processing regnetz_e8
# Processing repvgg_a2
# Processing repvgg_b0
# Processing repvgg_b1
# Processing repvgg_b1g4
# Processing repvgg_b2
# Processing repvgg_b2g4
# Processing repvgg_b3
# Processing repvgg_b3g4
# Processing res2net50_14w_8s
# Processing res2net50_26w_4s
# Processing res2net50_26w_6s
# Processing res2net50_26w_8s
# Processing res2net50_48w_2s
# Processing res2net101_26w_4s
# Processing res2next50
# Processing resnest14d
# Processing resnest26d
# Processing resnest50d
# Processing resnest50d_1s4x24d
# Processing resnest50d_4s2x40d
# Processing resnest101e
# Processing resnest200e
# Processing resnest269e
# Processing resnet18
# Processing resnet18d
# Processing resnet26
# Processing resnet26d
# Processing resnet26t
# Processing resnet32ts
# Processing resnet33ts
# Processing resnet34
# Processing resnet34d
# Processing resnet50
# Processing resnet50_gn
# Processing resnet50d
# Processing resnet50t
# Processing resnet51q
# Processing resnet61q
# Processing resnet101
# Processing resnet101d
# Processing resnet152
# Processing resnet152d
# Processing resnet200
# Processing resnet200d
# Processing resnetblur18
# Processing resnetblur50
# Processing resnetrs50
# Processing resnetrs101
# Processing resnetrs152
# Processing resnetrs200
# Processing resnetrs270
# Processing resnetrs350
# Processing resnetrs420
# Processing resnetv2_50
# Processing resnetv2_50d
# Processing resnetv2_50d_evob
# Processing resnetv2_50d_evos
# Processing resnetv2_50d_gn
# Processing resnetv2_50t
# Processing resnetv2_50x1_bit_distilled
# Processing resnetv2_50x1_bitm
# Processing resnetv2_50x1_bitm_in21k
# Processing resnetv2_50x3_bitm
# Processing resnetv2_50x3_bitm_in21k
# Processing resnetv2_101
# Processing resnetv2_101d
# Processing resnetv2_101x1_bitm
# Processing resnetv2_101x1_bitm_in21k
# Processing resnetv2_101x3_bitm
# Processing resnetv2_101x3_bitm_in21k
# Processing resnetv2_152
# Processing resnetv2_152d
# Processing resnetv2_152x2_bit_teacher
# Processing resnetv2_152x2_bit_teacher_384
# Processing resnetv2_152x2_bitm
# Processing resnetv2_152x2_bitm_in21k
# Processing resnetv2_152x4_bitm
# Processing resnetv2_152x4_bitm_in21k
# Processing resnext26ts
# Processing resnext50_32x4d
# Processing resnext50d_32x4d
# Processing resnext101_32x4d
# Processing resnext101_32x8d
# Processing resnext101_64x4d
# Processing rexnet_100
# Processing rexnet_130
# Processing rexnet_150
# Processing rexnet_200
# Processing rexnetr_100
# Processing rexnetr_130
# Processing rexnetr_150
# Processing rexnetr_200
# Processing sebotnet33ts_256
# Processing sehalonet33ts
# Processing selecsls42
# Processing selecsls42b
# Processing selecsls60
# Processing selecsls60b
# Processing selecsls84
# Processing semnasnet_050
# Processing semnasnet_075
# Processing semnasnet_100
# Processing semnasnet_140
# Processing senet154
# Processing seresnet18
# Processing seresnet33ts
# Processing seresnet34
# Processing seresnet50
# Processing seresnet50t
# Processing seresnet101
# Processing seresnet152
# Processing seresnet152d
# Processing seresnet200d
# Processing seresnet269d
# Processing seresnext26d_32x4d
# Processing seresnext26t_32x4d
# Processing seresnext26tn_32x4d
# Processing seresnext26ts
# Processing seresnext50_32x4d
# Processing seresnext101_32x4d
# Processing seresnext101_32x8d
# Processing skresnet18
# Processing skresnet34
# Processing skresnet50
# Processing skresnet50d
# Processing skresnext50_32x4d
# Processing spnasnet_100
# Processing ssl_resnet18
# Processing ssl_resnet50
# Processing ssl_resnext50_32x4d
# Processing ssl_resnext101_32x4d
# Processing ssl_resnext101_32x8d
# Processing ssl_resnext101_32x16d
# Processing swsl_resnet18
# Processing swsl_resnet50
# Processing swsl_resnext50_32x4d
# Processing swsl_resnext101_32x4d
# Processing swsl_resnext101_32x8d
# Processing swsl_resnext101_32x16d
# Processing tf_efficientnet_b0
# Processing tf_efficientnet_b0_ap
# Processing tf_efficientnet_b0_ns
# Processing tf_efficientnet_b1
